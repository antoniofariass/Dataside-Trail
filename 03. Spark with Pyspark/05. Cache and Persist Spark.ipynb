# %%
from pyspark import StorageLevel

# %%
spark.sql('use desp')
# Out:
# Out[2]: DataFrame[]

# %%
spark.sql('show tables').show()
# Out:
# +--------+---------+-----------+
# |database|tableName|isTemporary|
# +--------+---------+-----------+
# |    desp|churn_geo|      false|
# +--------+---------+-----------+

# %%
df = spark.sql('select * from churn_geo')

# %%
df.storageLevel
# Out:
# Out[7]: StorageLevel(False, False, False, False, 1)

# %%
df.cache()
# Out:
# Out[8]: DataFrame[CreditScore: int, Geography: string, Gender: string, Age: int, Tenure: int, Balance: int, NumOfProducts: int, HasCrCard: int, IsActiveMember: int, EstimatedSalary: int, Exited: int]

# %%
df.storageLevel
# Out:
# Out[9]: StorageLevel(True, True, False, True, 1)

# %%
df.persist(StorageLevel.DISK_ONLY)
# Out:
# Out[10]: DataFrame[CreditScore: int, Geography: string, Gender: string, Age: int, Tenure: int, Balance: int, NumOfProducts: int, HasCrCard: int, IsActiveMember: int, EstimatedSalary: int, Exited: int]
